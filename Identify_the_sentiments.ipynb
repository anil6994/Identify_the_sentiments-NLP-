# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /drive

# %%
import os
os.chdir('/drive/My Drive/deep learning/Hackathon')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
train_data = pd.read_csv('train_2kmZucJ.csv')
test_data = pd.read_csv('test_oJQbWVk.csv')

# %%
train_data.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %%
test_data.head()
# Out:
#      id                                              tweet
# 0  7921  I hate the new #iphone upgrade. Won't let me d...
# 1  7922  currently shitting my fucking pants. #apple #i...
# 2  7923  I'd like to puts some CD-ROMS on my iPad, is t...
# 3  7924  My ipod is officially dead. I lost all my pict...
# 4  7925  Been fighting iTunes all night! I only want th...

# %%
train_data.shape,test_data.shape
# Out:
# ((7920, 3), (1953, 2))

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7920 entries, 0 to 7919
# Data columns (total 3 columns):
# id       7920 non-null int64
# label    7920 non-null int64
# tweet    7920 non-null object
# dtypes: int64(2), object(1)
# memory usage: 185.8+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1953 entries, 0 to 1952
# Data columns (total 2 columns):
# id       1953 non-null int64
# tweet    1953 non-null object
# dtypes: int64(1), object(1)
# memory usage: 30.6+ KB

# %%
train_data.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# id       0
# tweet    0
# dtype: int64

# %%
train_data['label'].unique()
# Out:
# array([0, 1])

# %%
train_data['label'].value_counts()
# Out:
# 0    5894
# 1    2026
# Name: label, dtype: int64

# %%
import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.tag import pos_tag
from nltk.corpus import stopwords
from nltk import chunk

# %%
from sklearn .naive_bayes import MultinomialNB
from sklearn .feature_extraction.text import TfidfVectorizer,CountVectorizer

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
lem = WordNetLemmatizer()
stop = stopwords.words('english')

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
train_new_data = []
for data in train_data['tweet']:
      data = data.lower()
      data = re.sub(r'[^a-z0-9]',' ',data)
      data = re.sub(r'\s+',' ',data)
      data = [lem.lemmatize(word) for word in data.split() if word not in stop]
      data = ' '.join(data)
      train_new_data.append(data)

# %%
train_new_data
# Out:
# ['fingerprint pregnancy test http goo gl h1mfqv android apps beautiful cute health igers iphoneonly iphonesia iphone',
#  'finally transparant silicon case thanks uncle yay sony xperia sonyexperias http instagram com p yget5jc6jm',
#  'love would go talk makememories unplug relax iphone smartphone wifi connect http fb 6n3lsupcu',
#  'wired know george made way iphone cute daventry home http instagr p li 5 ujs4k',
#  'amazing service apple even talk question unless pay 19 95 stupid support',
#  'iphone software update fucked phone big time stupid iphones',
#  'happy u instapic instadaily u sony xperia xperiaz http instagram com p z9qgfwlvj7',
#  'new type c charger cable uk http www ebay co uk itm 112598674021 bay amazon etsy new year rob cross toby young evemun mcmafia taylor spectre 2018 newyear starting 2018 recipe technology samsunggalaxys9 iphonex pic twitter com pjiwq59wtc',
# ...

# %%
test_new_data = []
for data in test_data['tweet']:
      data = data.lower()
      data = re.sub(r'[^a-z0-9]',' ',data)
      data = re.sub(r'\s+',' ',data)
      data = [lem.lemmatize(word) for word in data.split() if word not in stop]
      data = ' '.join(data)
      test_new_data.append(data)

# %%
test_new_data
# Out:
# ['hate new iphone upgrade let download apps ugh apple suck',
#  'currently shitting fucking pant apple imac cashmoney raddest swagswagswag http instagr p uuis0bibzo',
#  'like put cd rom ipad possible yes block screen',
#  'ipod officially dead lost picture video 1d 5sos concert vet camp hatinglife sobbing',
#  'fighting itunes night want music paid',
#  'repost getbakednfried repostapp announce apple bourbon http www instagram com p bk5okhogwss',
#  'new apple software update really thing phone bad thing apple',
#  'baby iphone iphone6s gold new apple appleisbest 64gb geg nnt aaaaah http www instagram com p baux8eqtkez',
#  'confused take time set appointment still waiting 45 minute fact',
#  'fruit taste better pick apple healthy fruit nyc http ift tt 1ri7dyo pic twitter com zuo9thmek3',
#  'con mi buddy edgar buddy friend viviendo taller friendly hug sony smile sonrisa http instagram com p fasvzruzqi',
# ...

# %%
##  Converting data into vectors

# %%
tfidf_train = TfidfVectorizer()
cv_train = CountVectorizer()

# %%
X_tf_train= tfidf_train.fit_transform(train_new_data).toarray()
X_cv_train = cv_train.fit_transform(train_new_data). toarray()

# %%
X_tf_test= tfidf_train.transform(test_new_data).toarray()
X_cv_test = cv_train.transform(test_new_data).toarray()

# %%
tfidf_train.get_feature_names()
# Out:
# ['00',
#  '000',
#  '002',
#  '004',
#  '0051',
#  '007',
#  '00am',
#  '00pm',
#  '01',
#  '010111',
#  '010315',
#  '011',
#  '01108nartl',
#  '01204',
#  '01634',
#  '01924',
#  '01am',
#  '01amapril',
#  '01amjune',
#  '01ammay',
#  '01pm',
#  '01pmapril',
#  '01pmjune',
#  '01rcee',
#  '02',
#  '02pyow4aag',
#  '03',
#  '035glzwp4r',
#  '04',
#  '0490love',
#  '04t81f',
#  '05',
#  '06',
#  '07',
#  '0716',
#  '0777',
#  '07yilmaz242',
#  '08',
#  '08184820028',
#  '08t',
#  '09',
#  '09c753e42b04cafb66bb5676049a7cb8',
#  '0bao3i',
#  '0bfnzanwty',
#  '0cmcjv1vdj',
#  '0d9dzq0cxo',
#  '0dpfyzp4au',
#  '0dythia5w0',
#  '0ey7tmubxe',
#  '0eyq6dwgxy',
#  '0fcbzlaj9i',
#  '0ffj5vnrfo',
#  '0g',
#  '0gl7ddfrbk',
#  '0grfcyswij',
#  '0k3k1wc8fk',
#  '0k8h8yuufr',
#  '0kvbf',
#  '0livde',
#  '0ljymldhby',
#  '0mjjnomhpy',
#  '0mp',
#  '0n',
#  '0n4qiyjgye',
#  '0n85j',
#  '0oiou0ei5x',
#  '0p48k68rac',
#  '0pqzg',
#  '0psuz',
#  '0pxdkdj',
#  '0rx7h',
#  '0ssqhh798x',
#  '0sybds',
# ...

# %%
cv_train.get_feature_names()
# Out:
# ['00',
#  '000',
#  '002',
#  '004',
#  '0051',
#  '007',
#  '00am',
#  '00pm',
#  '01',
#  '010111',
#  '010315',
#  '011',
#  '01108nartl',
#  '01204',
#  '01634',
#  '01924',
#  '01am',
#  '01amapril',
#  '01amjune',
#  '01ammay',
#  '01pm',
#  '01pmapril',
#  '01pmjune',
#  '01rcee',
#  '02',
#  '02pyow4aag',
#  '03',
#  '035glzwp4r',
#  '04',
#  '0490love',
#  '04t81f',
#  '05',
#  '06',
#  '07',
#  '0716',
#  '0777',
#  '07yilmaz242',
#  '08',
#  '08184820028',
#  '08t',
#  '09',
#  '09c753e42b04cafb66bb5676049a7cb8',
#  '0bao3i',
#  '0bfnzanwty',
#  '0cmcjv1vdj',
#  '0d9dzq0cxo',
#  '0dpfyzp4au',
#  '0dythia5w0',
#  '0ey7tmubxe',
#  '0eyq6dwgxy',
#  '0fcbzlaj9i',
#  '0ffj5vnrfo',
#  '0g',
#  '0gl7ddfrbk',
#  '0grfcyswij',
#  '0k3k1wc8fk',
#  '0k8h8yuufr',
#  '0kvbf',
#  '0livde',
#  '0ljymldhby',
#  '0mjjnomhpy',
#  '0mp',
#  '0n',
#  '0n4qiyjgye',
#  '0n85j',
#  '0oiou0ei5x',
#  '0p48k68rac',
#  '0pqzg',
#  '0psuz',
#  '0pxdkdj',
#  '0rx7h',
#  '0ssqhh798x',
#  '0sybds',
# ...

# %%
y = train_data['label']

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
LGR_Classifier = LogisticRegression()
LGR_Classifier.fit(X_tf_train,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions_train_LGR = LGR_Classifier.predict(X_tf_train)

# %%
# Train Gaussian Naive Baye Model
MULT_Classifier = MultinomialNB()
MULT_Classifier.fit(X_tf_train,y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
predictions_train_MULT= MULT_Classifier.predict(X_tf_train)

# %%
# Train Decision Tree Model
DTC_Classifier = DecisionTreeClassifier()
DTC_Classifier.fit(X_tf_train,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predictions_train_DTC = DTC_Classifier.predict(X_tf_train)

# %%
# Train KNeighborsClassifier Model
KNN_Classifier = KNeighborsClassifier()
KNN_Classifier.fit(X_tf_train,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
predictions_train_KNN=KNN_Classifier.predict(X_tf_train)

# %%
# Train Support Vector Machine 
SVC_Classifier=SVC()
SVC_Classifier.fit(X_tf_train,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
predictions_train_SVC = SVC_Classifier.predict(X_tf_train)

# %%
#RFC classifier
RFC_Classifier = RandomForestClassifier()
RFC_Classifier.fit(X_tf_train,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predictions_train_RFC = RFC_Classifier.predict(X_tf_train)

# %%
print(classification_report(y,predictions_train_LGR))
print("Accuracy:",accuracy_score(y,predictions_train_LGR))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      5894
#            1       0.89      0.83      0.86      2026
#
#     accuracy                           0.93      7920
#    macro avg       0.92      0.90      0.91      7920
# weighted avg       0.93      0.93      0.93      7920
#
# Accuracy: 0.9318181818181818

# %%
print(classification_report(y,predictions_train_MULT))
print("Accuracy:",accuracy_score(y,predictions_train_MULT))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95      5894
#            1       0.94      0.72      0.82      2026
#
#     accuracy                           0.92      7920
#    macro avg       0.93      0.85      0.88      7920
# weighted avg       0.92      0.92      0.91      7920
#
# Accuracy: 0.9179292929292929

# %%
print(classification_report(y,predictions_train_DTC))
print("Accuracy:",accuracy_score(y,predictions_train_DTC))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5894
#            1       1.00      1.00      1.00      2026
#
#     accuracy                           1.00      7920
#    macro avg       1.00      1.00      1.00      7920
# weighted avg       1.00      1.00      1.00      7920
#
# Accuracy: 0.9998737373737374

# %%
print(classification_report(y,predictions_train_KNN))
print("Accuracy:",accuracy_score(y,predictions_train_KNN))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      5894
#            1       0.81      0.85      0.83      2026
#
#     accuracy                           0.91      7920
#    macro avg       0.88      0.89      0.89      7920
# weighted avg       0.91      0.91      0.91      7920
#
# Accuracy: 0.9116161616161617

# %%
print(classification_report(y,predictions_train_SVC))
print("Accuracy:",accuracy_score(y,predictions_train_SVC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85      5894
#            1       0.00      0.00      0.00      2026
#
#     accuracy                           0.74      7920
#    macro avg       0.37      0.50      0.43      7920
# weighted avg       0.55      0.74      0.64      7920
#
# Accuracy: 0.7441919191919192
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(classification_report(y,predictions_train_RFC))
print("Accuracy:",accuracy_score(y,predictions_train_RFC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5894
#            1       0.99      0.98      0.98      2026
#
#     accuracy                           0.99      7920
#    macro avg       0.99      0.99      0.99      7920
# weighted avg       0.99      0.99      0.99      7920
#
# Accuracy: 0.9921717171717171

# %%
from sklearn.model_selection import GridSearchCV,KFold
import time

# %%
from sklearn.model_selection import StratifiedKFold,GridSearchCV
parameter_grid = {'n_estimators' :[5,10,25,50,100],'criterion' : ['gini','entropy'],'max_features': [1,2]}
cross_validation = StratifiedKFold(n_splits = 10, shuffle= True , random_state= 101)
clf3=GridSearchCV(estimator=RandomForestClassifier(),param_grid=parameter_grid,scoring='accuracy',cv=cross_validation)
start = time.time()
clf3.fit(X_tf_train,y)
end = time.time()
print(end-start)
# Out:
# 1773.0701370239258

# %%
clf3.best_score_
# Out:
# 0.8882575757575758

# %%
print('Best parameters: {}'.format(clf3.best_params_))
clf3.best_estimator_
# Out:
# Best parameters: {'criterion': 'gini', 'max_features': 2, 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=2, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
test = clf3.predict(X_tf_test)

# %%
test_pred = pd.DataFrame(test,columns=['label'])

# %%
test_pred
# Out:
#       label
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
# ...     ...
# 1948      0
# 1949      0
# 1950      1
# 1951      1
# 1952      0
#
# [1953 rows x 1 columns]

# %%
test_data['id']
# Out:
# 0       7921
# 1       7922
# 2       7923
# 3       7924
# 4       7925
#         ...
# 1948    9869
# 1949    9870
# 1950    9871
# 1951    9872
# 1952    9873
# Name: id, Length: 1953, dtype: int64

# %%
final_pred = pd.concat([test_data['id'],test_pred],axis = 1)
final_pred
# Out:
#         id  label
# 0     7921      1
# 1     7922      0
# 2     7923      1
# 3     7924      1
# 4     7925      1
# ...    ...    ...
# 1948  9869      0
# 1949  9870      0
# 1950  9871      1
# 1951  9872      1
# 1952  9873      0
#
# [1953 rows x 2 columns]

# %%
final_pred.to_csv('/drive/My Drive/deep learning/Hackathon/final_pred.csv',index= False)
